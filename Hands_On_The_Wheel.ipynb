# %%
# !uv pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.95 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 46.7/112.6 GB disk)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="lE3sZOejqYXmq71ajiph")
project = rf.workspace("nours-workspace-c7tpe").project("hands-on-the-wheel-wny87")
version = project.version(1)
dataset = version.download("yolo26")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to hands-on-the-wheel-1 in yolo26:: 100%|██████████| 5805/5805 [00:00<00:00, 7532.36it/s]

# %%
# !yolo train model=yolo26n.pt data='/content/hands-on-the-wheel-1/data.yaml' epochs=30 imgsz=512
# Out:
# ...
# Ultralytics 8.4.95 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
